# %%
import pandas as pd

# %% [markdown]
# How many observations and features do you have?

# %%
data = pd.read_csv('C:\Programação\Becode\Projects\DataNeverMinds\immo-eliza-scraping-dataneverminds\data\property_data.csv',sep=',')
data
# Out:
#        Property ID         Locality name Postal code    Price  \
# 0         10666139                 Lasne        1380   995000
# 1         10832715             Etterbeek        1040  1150000
# 2         10511833  Woluwe-Saint-Lambert        1200  1190000
# 3         11058109               Antwerp        2018  1250000
# 4         10808476            Anderlecht        1070  1295000
# ...            ...                   ...         ...      ...
# 17485     10796912              Stavelot        4970   410000
# 17486     11105656                  Paal        3583   346866
# 17487     11105640              Duisburg        3080   768253
# 17488     11105631                Herent        3020   501659
# 17489     11105624              Borgloon        3840   324710
#
#       Type of property Subtype of property Type of sale  Number of Rooms  \
# 0                HOUSE               VILLA  BUY_REGULAR                6
# 1                HOUSE               HOUSE  BUY_REGULAR                6
# 2                HOUSE               HOUSE  BUY_REGULAR                6
# 3                HOUSE             MANSION  BUY_REGULAR                8
# 4                HOUSE     APARTMENT_BLOCK  BUY_REGULAR                9
# ...                ...                 ...          ...              ...
# 17485            HOUSE               VILLA  BUY_REGULAR                6
# 17486            HOUSE  MIXED_USE_BUILDING  BUY_REGULAR                3
# 17487            HOUSE  MIXED_USE_BUILDING  BUY_REGULAR                3
# 17488            HOUSE  MIXED_USE_BUILDING  BUY_REGULAR                3
# 17489            HOUSE  MIXED_USE_BUILDING  BUY_REGULAR                3
#
#        Living area  Furnished  Open fire  Terrace Surface  Garden Surface  \
# 0            300.0          0          0              NaN             NaN
# 1            300.0          0          0             40.0           150.0
# 2            304.0          0          0             33.0           353.0
# 3            360.0          0          0              NaN            36.0
# 4            580.0          0          0              NaN             NaN
# ...            ...        ...        ...              ...             ...
# 17485        193.0          0          0              NaN           965.0
# 17486        143.0          0          0              NaN             NaN
# 17487        207.0          0          0              NaN             NaN
# 17488        198.0          0          0              NaN             NaN
# 17489        170.0          0          0              NaN             NaN
#
#        Swimming pool  Toilets  Surface of good  Number of facades  \
# 0                  0      1.0          14631.0                4.0
# 1                  0      4.0            260.0                2.0
# 2                  0      3.0            475.0                2.0
# 3                  0      6.0            173.0                2.0
# 4                  0      9.0            140.0                3.0
# ...              ...      ...              ...                ...
# 17485              0      2.0           1121.0                4.0
# 17486              0      1.0            434.0                NaN
# 17487              0      2.0            781.0                NaN
# 17488              0      1.0            860.0                NaN
# 17489              0      NaN            515.0                NaN
#
#       Building State    Kitchen_type  Kitchen
# 0         TO_RESTORE             NaN        0
# 1             AS_NEW  HYPER_EQUIPPED        1
# 2               GOOD       INSTALLED        1
# 3               GOOD       INSTALLED        1
# 4               GOOD   SEMI_EQUIPPED        1
# ...              ...             ...      ...
# 17485           GOOD       INSTALLED        1
# 17486            NaN       INSTALLED        1
# 17487            NaN       INSTALLED        1
# 17488            NaN       INSTALLED        1
# 17489           GOOD       INSTALLED        1
#
# [17490 rows x 20 columns]

# %% [markdown]
# What is the proportion of missing values per column?

# %%
missing_value = data.isnull().mean()
missing_value
# Out:
# Property ID            0.000000
# Locality name          0.000000
# Postal code            0.000000
# Price                  0.000000
# Type of property       0.000000
# Subtype of property    0.000000
# Type of sale           0.000000
# Number of Rooms        0.000000
# Living area            0.048256
# Furnished              0.000000
# Open fire              0.000000
# Terrace Surface        0.642882
# Garden Surface         0.712236
# Swimming pool          0.000000
# Toilets                0.200743
# Surface of good        0.210577
# Number of facades      0.212407
# Building State         0.225386
# Kitchen_type           0.371812
# Kitchen                0.000000
# dtype: float64

# %% [markdown]
# Which variables would you delete and why?

# %%
#i would not take any of them
data.shape
# Out:
# (17490, 20)

# %% [markdown]
# What variables are most subject to outliers?

# %%
data.head(5)
# Out:
#    Property ID         Locality name Postal code    Price Type of property  \
# 0     10666139                 Lasne        1380   995000            HOUSE
# 1     10832715             Etterbeek        1040  1150000            HOUSE
# 2     10511833  Woluwe-Saint-Lambert        1200  1190000            HOUSE
# 3     11058109               Antwerp        2018  1250000            HOUSE
# 4     10808476            Anderlecht        1070  1295000            HOUSE
#
#   Subtype of property Type of sale  Number of Rooms  Living area  Furnished  \
# 0               VILLA  BUY_REGULAR                6        300.0          0
# 1               HOUSE  BUY_REGULAR                6        300.0          0
# 2               HOUSE  BUY_REGULAR                6        304.0          0
# 3             MANSION  BUY_REGULAR                8        360.0          0
# 4     APARTMENT_BLOCK  BUY_REGULAR                9        580.0          0
#
#    Open fire  Terrace Surface  Garden Surface  Swimming pool  Toilets  \
# 0          0              NaN             NaN              0      1.0
# 1          0             40.0           150.0              0      4.0
# 2          0             33.0           353.0              0      3.0
# 3          0              NaN            36.0              0      6.0
# 4          0              NaN             NaN              0      9.0
#
#    Surface of good  Number of facades Building State    Kitchen_type  Kitchen
# 0          14631.0                4.0     TO_RESTORE             NaN        0
# 1            260.0                2.0         AS_NEW  HYPER_EQUIPPED        1
# 2            475.0                2.0           GOOD       INSTALLED        1
# 3            173.0                2.0           GOOD       INSTALLED        1
# 4            140.0                3.0           GOOD   SEMI_EQUIPPED        1

# %% [markdown]
# How many qualitative and quantitative variables are there? How would you transform the qualitative values into numerical values?

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 data.index('Property ID')
#
# TypeError: 'RangeIndex' object is not callable

# %% [markdown]
# What is the correlation between the variables and the price? Why do you think some variables are more correlated than others?

# %% [markdown]
# How are the variables themselves correlated to each other? Can you find groups of variables that are correlated together?

# %% [markdown]
# How are the number of properties distributed according to their surface?

# %% [markdown]
# Which five variables do you consider the most important and why?

# %% [markdown]
# What are the least/most expensive municipalities in Belgium/Wallonia/Flanders? (in terms of price per m², average price, and median price)
