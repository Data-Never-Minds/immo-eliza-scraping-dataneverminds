# %%
import requests
from bs4 import BeautifulSoup
import json

url = "https://www.immoweb.be/fr/annonce/maison/a-vendre/ixelles/1050/11075842"
r = requests.get(url)
c = r.content
#print(r.status_code)

soup = BeautifulSoup(c, "html.parser")

# %%
script_tags = soup.find_all("script", attrs={"type": "text/javascript"})

for script in script_tags:
    if "window.classified" in script.get_text():
        script_text = script.get_text()
        json_string = script_text.split('window.classified = ', 1)[1]
        json_string = json_string.rsplit(';', 1)[0]

        classified_data = json.loads(json_string)
        print(classified_data)
        break
# Out:
# {'id': 11075842, 'cluster': None, 'customers': [{'id': 2575488, 'type': 'AGENCY', 'email': 'storage4563_152@importfrommedia.be', 'logoUrl': 'https://static.immoweb.be/logos/2575488.gif?cache=2024521001663', 'phoneNumber': '+3223186266', 'mobileNumber': None, 'name': 'We Invest Bruxelles', 'website': 'http://www.weinvest.be', 'location': {'country': 'Belgique', 'region': None, 'province': 'Bruxelles', 'district': 'Bruxelles', 'locality': 'Auderghem', 'postalCode': '1160', 'street': 'Place Communale 8', 'number': None, 'box': None, 'propertyName': None, 'floor': None, 'latitude': 50.8156957, 'longitude': 4.4291316, 'distance': None, 'approximated': None, 'regionCode': None, 'type': None, 'hasSeaView': None, 'pointsOfInterest': None, 'placeName': None}, 'ipiNo': '507630', 'isOwner': True, 'contactHoursMobile': 'anytime', 'contactHoursLandline': 'anytime', 'salesRepresentative': None, 'features': {'page404': True, 'investorFlag': False, 'relatedClassifieds': True, 'leafletsCTA': False, 'leadQualification': True, 'recommendation': True}}], 'premiumProjectPage': {'medias': None, 'options': None, 'promoter': None, 'tabs': None}, 'flags': {'isPublicSale': False, 'isNewClassified': False, 'isNewPrice': False, 'isInvestmentProject': False, 'isNewlyBuilt': False, 'isNotarySale': None, 'isLifeAnnuitySale': False, 'adQuality': None, 'date': None, 'priceSqm': None, 'price': None, 'default': None, 'isSoldOrRented': False, 'isLowEnergy': None, 'percentSold': None, 'isPassiveHouse': None, 'isNewRealEstateProject': False, 'isAnInteractiveSale': None, 'isUnderOption': False}, 'media': {'pictures': [{'smallUrl': 'https://static.immoweb.be/photos/1/1/0/7/5/8/4/2/11075842_1.gif?cache=20240116124849', 'mediumUrl': 'https://static.immoweb.be/photos/1/1/0/7/5/8/4/2/M_11075842_1.jpg?cache=20240116124849', 'largeUrl': 'https://static.immoweb.be/photos/1/1/0/7/5/8/4/2/11075842_1.jpg?cache=20240116124849', 'isVertical': False}, {'smallUrl': 'https://static.immoweb.be/photos/1/1/0/7/5/8/4/2/11075842_2.gif?cache=20240116124849', 'mediumUrl': 'https://static.immoweb.be/photos/1/1/0/7/5/8/4/2/M_11075842_2.jpg?cache=20240116124849', 'largeUrl': 'https://static.immoweb.be/photos/1/1/0/7/5/8/4/2/11075842_2.jpg?cache=20240116124849', 'isVertical': False}, {'smallUrl': 'https://static.immoweb.be/photos/1/1/0/7/5/8/4/2/11075842_3.gif?cache=20240116124849', 'mediumUrl': 'https://static.immoweb.be/photos/1/1/0/7/5/8/4/2/M_11075842_3.jpg?cache=20240116124849', 'largeUrl': 'https://static.immoweb.be/photos/1/1/0/7/5/8/4/2/11075842_3.jpg?cache=20240116124849', 'isVertical': False}, {'smallUrl': 'https://static.immoweb.be/photos/1/1/0/7/5/8/4/2/11075842_4.gif?cache=20240116124849', 'mediumUrl': 'https://static.immoweb.be/photos/1/1/0/7/5/8/4/2/M_11075842_4.jpg?cache=20240116124849', 'largeUrl': 'https://static.immoweb.be/photos/1/1/0/7/5/8/4/2/11075842_4.jpg?cache=20240116124849', 'isVertical': False}, {'smallUrl': 'https://static.immoweb.be/photos/1/1/0/7/5/8/4/2/11075842_5.gif?cache=20240116124849', 'mediumUrl': 'https://static.immoweb.be/photos/1/1/0/7/5/8/4/2/M_11075842_5.jpg?cache=20240116124849', 'largeUrl': 'https://static.immoweb.be/photos/1/1/0/7/5/8/4/2/11075842_5.jpg?cache=20240116124849', 'isVertical': False}, {'smallUrl': 'https://static.immoweb.be/photos/1/1/0/7/5/8/4/2/11075842_6.gif?cache=20240116124849', 'mediumUrl': 'https://static.immoweb.be/photos/1/1/0/7/5/8/4/2/M_11075842_6.jpg?cache=20240116124849', 'largeUrl': 'https://static.immoweb.be/photos/1/1/0/7/5/8/4/2/11075842_6.jpg?cache=20240116124849', 'isVertical': False}, {'smallUrl': 'https://static.immoweb.be/photos/1/1/0/7/5/8/4/2/11075842_7.gif?cache=20240116124849', 'mediumUrl': 'https://static.immoweb.be/photos/1/1/0/7/5/8/4/2/M_11075842_7.jpg?cache=20240116124849', 'largeUrl': 'https://static.immoweb.be/photos/1/1/0/7/5/8/4/2/11075842_7.jpg?cache=20240116124849', 'isVertical': False}, {'smallUrl': 'https://static.immoweb.be/photos/1/1/0/7/5/8/4/2/11075842_8.gif?cache=20240116124849', 'mediumUrl ...

# %%
print("Property ID:", classified_data['id'])
# Out:
# Property ID: 11075842

# %%
location = my_dict.get('location', {})
locality = location.get('locality', 'Default Value')
print("Locality name:", locality)
# Out:
# Locality name: Ixelles

# %%
postalCode = my_dict['location']['postalCode']
print("Postal code:", postalCode)
# Out:
# Postal code: 1050

# %%
subtype = my_dict.get('property', {}).get('subtype', 'Default Subtype')
print("Subtype:", subtype)
# Out:
# Subtype: Default Subtype

# %%
fireplace_exists = my_dict['property'].get('fireplaceExists', 'Default Value')
print("Fireplace Exists:", fireplace_exists)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 fireplace_exists = my_dict['property'].get('fireplaceExists', 'Default Value')
#       2 print("Fireplace Exists:", fireplace_exists)
#
# KeyError: 'property'

# %% [raw]
# propsubtype = my_dict['subtype']
# print("Type of property:", propsubtype)

# %%
Property ID
Locality name
Postal code
Price
Type of property (house or apartment)
Subtype of property (bungalow, chalet, mansion, ...)
Type of sale (note: exclude life sales)
Number of rooms
Living area (area in m²)
Equipped kitchen (0/1)
Furnished (0/1)
Open fire (0/1)
Terrace (area in m² or null if no terrace)
Garden (area in m² or null if no garden)
Surface of good
Number of facades
Swimming pool (0/1)
State of building (new, to be renovated, ...)

# %%
my_dict = classified_data['property']

# %%
living_area = my_dict['netHabitableSurface']
print("Living area:", living_area)
# Out:
# Living area: 243

# %%
kitchen = my_dict['kitchen']
if kitchen:
    print("Equipped kitchen:", 1)
else:
    print("Equipped kitchen:", 0)
# Out:
# Equipped kitchen: 1

# %%
hasSwimmingPool = my_dict['hasSwimmingPool']
if hasSwimmingPool:
    print("Swimming pool:", 1)
else:
    print("Swimming pool:", 0)
# Out:
# Swimming pool: 0

# %%
facadeCount = my_dict['facadeCount']
if facadeCount:
    print("Number of facades:", facadeCount)
else:
    print("Number of facades not found")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 facadeCount = my_dict['facadeCount']
#       2 if facadeCount:
#       3     print("Number of facades:", facadeCount)
#
# KeyError: 'facadeCount'

# %%
fireplaceCount = my_dict['fireplaceCount']
if fireplaceCount:
    print("Open fire:", 1)
else:
    print("Open fire:", 0)
# Out:
# Open fire: 0

# %%
terraceSurface = my_dict['terraceSurface']
if terraceSurface:
    print("Terrace:", terraceSurface)
else:
    print("Terrace:", 0)
# Out:
# Terrace: 0

# %%
gardenSurface = my_dict['gardenSurface']
if gardenSurface:
    print("Garden:", gardenSurface)
else:
    print("Garden:", 0)
# Out:
# Garden: 0

# %%
netHabitableSurface = my_dict['netHabitableSurface']
if netHabitableSurface:
    print("Living area in m²:", netHabitableSurface)
else:
    print("Living area not found")
# Out:
# Living area in m²: 243

# %%
isFurnished = my_dict['sale']['isFurnished']
if isFurnished:
    print("isFurnished:", isFurnished)
else:
    print("isFurnished:", 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 isFurnished = my_dict['sale']['isFurnished']
#       2 if isFurnished:
#       3     print("isFurnished:", isFurnished)
#
# KeyError: 'sale'

# %%
bedroomCount
isFurnished = my_dict['sale']['isFurnished']
if isFurnished:
    print("isFurnished:", isFurnished)
else:
    print("isFurnished:", 0)

# %%
print(type(classified_data['property']))
# Out:
# <class 'dict'>

# %%
script_tags = soup.find_all("script", attrs={"type": "text/javascript"})

for script in script_tags:
    if "window.classified" in script.get_text():
        classified_script = script
        print(classified_script.text)
        break
# Out:
#             window.classified = {"id":11075842,"cluster":null,"customers":[{"id":2575488,"type":"AGENCY","email":"storage4563_152@importfrommedia.be","logoUrl":"https:\/\/static.immoweb.be\/logos\/2575488.gif?cache=2024521001663","phoneNumber":"+3223186266","mobileNumber":null,"name":"We Invest Bruxelles","website":"http:\/\/www.weinvest.be","location":{"country":"Belgique","region":null,"province":"Bruxelles","district":"Bruxelles","locality":"Auderghem","postalCode":"1160","street":"Place Communale 8","number":null,"box":null,"propertyName":null,"floor":null,"latitude":50.8156957,"longitude":4.4291316,"distance":null,"approximated":null,"regionCode":null,"type":null,"hasSeaView":null,"pointsOfInterest":null,"placeName":null},"ipiNo":"507630","isOwner":true,"contactHoursMobile":"anytime","contactHoursLandline":"anytime","salesRepresentative":null,"features":{"page404":true,"investorFlag":false,"relatedClassifieds":true,"leafletsCTA":false,"leadQualification":true,"recommendation":true}}],"premiumProjectPage":{"medias":null,"options":null,"promoter":null,"tabs":null},"flags":{"isPublicSale":false,"isNewClassified":false,"isNewPrice":false,"isInvestmentProject":false,"isNewlyBuilt":false,"isNotarySale":null,"isLifeAnnuitySale":false,"adQuality":null,"date":null,"priceSqm":null,"price":null,"default":null,"isSoldOrRented":false,"isLowEnergy":null,"percentSold":null,"isPassiveHouse":null,"isNewRealEstateProject":false,"isAnInteractiveSale":null,"isUnderOption":false},"media":{"pictures":[{"smallUrl":"https:\/\/static.immoweb.be\/photos\/1\/1\/0\/7\/5\/8\/4\/2\/11075842_1.gif?cache=20240116124849","mediumUrl":"https:\/\/static.immoweb.be\/photos\/1\/1\/0\/7\/5\/8\/4\/2\/M_11075842_1.jpg?cache=20240116124849","largeUrl":"https:\/\/static.immoweb.be\/photos\/1\/1\/0\/7\/5\/8\/4\/2\/11075842_1.jpg?cache=20240116124849","isVertical":false},{"smallUrl":"https:\/\/static.immoweb.be\/photos\/1\/1\/0\/7\/5\/8\/4\/2\/11075842_2.gif?cache=20240116124849","mediumUrl":"https:\/\/static.immoweb.be\/photos\/1\/1\/0\/7\/5\/8\/4\/2\/M_11075842_2.jpg?cache=20240116124849","largeUrl":"https:\/\/static.immoweb.be\/photos\/1\/1\/0\/7\/5\/8\/4\/2\/11075842_2.jpg?cache=20240116124849","isVertical":false},{"smallUrl":"https:\/\/static.immoweb.be\/photos\/1\/1\/0\/7\/5\/8\/4\/2\/11075842_3.gif?cache=20240116124849","mediumUrl":"https:\/\/static.immoweb.be\/photos\/1\/1\/0\/7\/5\/8\/4\/2\/M_11075842_3.jpg?cache=20240116124849","largeUrl":"https:\/\/static.immoweb.be\/photos\/1\/1\/0\/7\/5\/8\/4\/2\/11075842_3.jpg?cache=20240116124849","isVertical":false},{"smallUrl":"https:\/\/static.immoweb.be\/photos\/1\/1\/0\/7\/5\/8\/4\/2\/11075842_4.gif?cache=20240116124849","mediumUrl":"https:\/\/static.immoweb.be\/photos\/1\/1\/0\/7\/5\/8\/4\/2\/M_11075842_4.jpg?cache=20240116124849","largeUrl":"https:\/\/static.immoweb.be\/photos\/1\/1\/0\/7\/5\/8\/4\/2\/11075842_4.jpg?cache=20240116124849","isVertical":false},{"smallUrl":"https:\/\/static.immoweb.be\/photos\/1\/1\/0\/7\/5\/8\/4\/2\/11075842_5.gif?cache=20240116124849","mediumUrl":"https:\/\/static.immoweb.be\/photos\/1\/1\/0\/7\/5\/8\/4\/2\/M_11075842_5.jpg?cache=20240116124849","largeUrl":"https:\/\/static.immoweb.be\/photos\/1\/1\/0\/7\/5\/8\/4\/2\/11075842_5.jpg?cache=20240116124849","isVertical":false},{"smallUrl":"https:\/\/static.immoweb.be\/photos\/1\/1\/0\/7\/5\/8\/4\/2\/11075842_6.gif?cache=20240116124849","mediumUrl":"https:\/\/static.immoweb.be\/photos\/1\/1\/0\/7\/5\/8\/4\/2\/M_11075842_6.jpg?cache=20240116124849","largeUrl":"https:\/\/static.immoweb.be\/photos\/1\/1\/0\/7\/5\/8\/4\/2\/11075842_6.jpg?cache=20240116124849","isVertical":false},{"smallUrl":"https:\/\/static.immoweb.be\/photos\/1\/1\/0\/7\/5\/8\/4\/2\/11075842_7.gif?cache=20240116124849","mediumUrl":"https:\/\/static.immoweb.be\/photos\/1\/1\/0\/7\/5\/8\/4\/2\/M_11075842_7.jpg?cache=20240116124849","largeUrl":"https:\/\/static.immoweb.be\/photos\/1\/1\/0\/7\/5\/8\/4\/2\/11075842_7.jpg?cache=20240116124849","isVertical":false},{"smallUrl": ...

# %%
script = soup.findAll('span')[1].string
data = script.split("a")
#data = script.split("bootstrapData['menuMonthWeeks'] = ", 1)[-1].rsplit(';', 1)[0]
#data = json.loads(data)
data
# Out:
# ['M', 'ison']

# %%
if soup.find("accordion__content"):
    soup.find("accordion__content").decompose()


print(soup.text.strip())
# Out:
# Maison à vendre à Ixelles - 595 000 € - 4 chambres - 243m² - Immoweb
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Type de bien
#
#
#
# Appartement
#
#
#
#
# Maison
#
#
#
#
# Maison et appartement
#
#
#
#
# Projet neuf - Appartements
#
#
#
#
# Projet neuf - Maisons
#
#
#
#
# Maisons à construire
#
#
#
#
#
#
#
#
#
#
#
# Recherche avancée
#
#
#
#
#
#
#
# Recherche sur la carte
#
#
#
#
#
#
#
# Uniquement les biens avec visite virtuelle
#
#
#
#
# Recherche avec un Immoweb code
#
#
#
#
#
#
#
#
#
#
#                     Découvrez nos projets immobiliers neufs
#
#
#
#                         Découvrir
#
#
#
#
#
#
#
#
#
#
#
#
#
# À louer
#
#
#
#
# Type de bien
#
#
#
# Appartement
#
#
#
#
# Maison
#
#
#
#
# Maison et appartement
#
#
#
#
# Logement étudiant
#
#
#
#
# Commerce
#
#
#
#
#
#
#
#
#
#
#
# Recherche avancée
#
#
#
#
#
#
#
# Recherche sur la carte
#
#
#
#
#
#
#
# Uniquement les biens avec visite virtuelle
#
#
#
#
# Recherche avec un Immoweb code
#
#
#
#
#
#
#
#
#
#
#                     Découvrez nos projets immobiliers neufs
#
#
#
#                         Découvrir
#
#
#
#
#
#
#
#
#
#
#
#
#
# Estimer
#
#
#
#
# Estimer
#
#
#
# Estimer mon bien en ligne
#
#
#
#
#
#
#
# Contacter une agence
#
#
#
#
#
# Prix immobilier
#
#
#
# Carte des prix au m² en Belgique
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     Découvrez nos projets immobiliers neufs
#
#
#
#                         Découvrir
#
#
#
#
#
#
#
#
#
#
#
#
#
# Professionnels
#
#
#
#
# Trouver un professionnel
#
#
#
# Trouver une agence
#
#
#
#
# Trouver un notaire
#
#
#
#
# Trouver un promoteur immobilier
#
#
#
#
#
#
#
#
#
#
#                     Découvrez nos projets immobiliers neufs
#
#
#
#                         Découvrir
#
#
#
#
#
#
#
#
#
#
#
#
#
# Services
#
#
#
#
# À votre service
#
#
#
# Crédit hypothécaire
#
#
#
#
# Assurance habitation - incendie
#
#
#
#
#
#
#
# Assurance loyer garanti
#
#
#
#
#
#
#
#
# Propriétaire
#
#
#
# Conseils à la vente
#
#
#
#
#
#
#
# Voir tous les services
#
#
#
#
#
#
#
#
# Conseils et inspiration
#
#
#
# Immoweb Blog
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     Découvrez nos projets immobiliers neufs
#
#
#
#                         Découvrir
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Publier une annonce
#
#
#
#
#
#
#
#
#
# Se connecter
#
#
#
#
#
#
#
#
#
#
#
#                             fr
#
#
#
#
#
#
#
#
#
#
#
#                                     en
#
#
#
#
#
#
#
#
#
#
#                                     fr
#
#
#
#
#
#
#                                     nl
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Javascript est requis
# Veuillez utiliser un autre navigateur avec Javascript activé.
#
#
#
#
#
#
#
#
#
#
#
#
#                 Vers le contenu
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                     Maison
#                                                         à vendre
#
#
#
# Faire offre à partir de
# 595 000 € 595000€
#
#
#
#
#
#                                                                                     4 chambres
#                                                                                         |
#                                                                                         243
#
#
#                                         m²
#
#                                         mètres carrés
#
#
#
#
#
#                         Immoweb code : 11075842
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     Immoweb code : 11075842
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aperçu
#
#
#
#
#
#
#
#
#
#                                             4 chambres
#
#
#
#
#
#
#
#
#                                             1 salle de bains
#
#
#
#
#
#
#
#
#
#
#                                             243
#
#
#                                                     m²
#
#                                                     mètres carrés
#
#
#                                             habitables
#
#
#
#
#
#
#
#
#                                             110
#
#
#                                                     m²
#
#                                                     mètres carrés
#
#
#                                             de terrain
#
#
#
#
#
#
#
#
#
#
#                                         Disponible le : 15/01/2024
#
#
#
#
#
#
#
#
#
#
#                                     Visite virtuelle
#
#
#
#
#
#
#
#
#
#
#
#
# Description
#
#
#
# Ixelles - chouette maison de commerce idéalement située.
#
#                         Informations & visites : +32 2 315 51 71 Ixelles - Idéalement située dans une rue calme, à proximité de l'Avenue Louise, du quartier de la Toison d'Or, du Boulevard de Waterloo et proche de toutes les commodités (transports, commerces, écoles, restaurants, ...), We Invest vous propose cette chouette maison de commerce (2 étages reconnues) à rénover de +/- 280m2 brut + cour intérieur. Elle est actuellement aménagée comme suit : au rez-de-chaussée : un logement avec grand hall d'entrée, salon, salle à manger, cuisine équipée, salle de douche avec wc, buanderie et chambre à coucher de +- 17m2. Au 1er étage : un logement avec salon/salle à manger, cuisine semi-équipée, chambre à coucher de +- 17m2, salle de bain et wc. Au 2ème étage : un logement avec cuisine, salon/salle à manger, salle de douche avec wc et chambre à coucher de +- 17m2. Au 3ème étage : cuisine semi-équipée, salon/salle à manger avec mezzanine, chambre à coucher de +- 17m2, salle de douche et wc. Au sous-sol: caves et local technique. PEB : F, D-,D & G. Chaudières au gaz individuelles. Double vitrage. Disponible à l'acte. A visiter sans plus tarder!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contacter
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                             Nos maisons hors de la belgique
#
#
#
#                                 Maison à vendre France
#
#
#
#
#                                 Maison à vendre Espagne
#
#
#
#
#                                 Maison à vendre Italie
#
#
#
#
#                                 Maison à vendre Luxembourg
#
#
#
#
#                                 Maison à vendre Pays-bas
#
#
#
#
#
#
#
#
#
#
#
# À propos
#
#
# Immoweb
#
#
# Presse
#
#
# Emplois
#
#
#
#                         Groupe Axel Springer
#
#
# SeLoger.com
#
#
#
#
#                         Immowelt.de
#
#
#
#
#
# Outils
#
#
#
#                         Estimer mon bien
#
#
#
#                         Carte des prix au m² en Belgique
#
#
#
#                         Crédit hypothécaire
#
#
#
#                         Assurances
#
#
#
#                             Check-list déménagement
#
#
#
#
# Aide
#
#
#
#                         FAQ
#
#
#
#                         Fraude
#
#
#
#                         Accessibilité
#
#
#
#                         Contactez-nous
#
#
#
#
# Suivez-nous
#
#
#
#                             Immoweb Blog
#
#
#
#                         Facebook
#
#
#
#
#                         Twitter
#
#
#
#
#                         LinkedIn
#
#
#
#
#
# © Immoweb SA/NV 2024
#
#
#
# 						Conditions d'utilisation
#
#
#
#                         Gestion des cookies
#
#
#
# 						Vie privée
#
#
#
#
#
#
# 				164 - 9244277aa9935b862b993da47ccc3acea6d3c280 - i-09f9ddce4987a82d4

# %%
result = " ".join(soup.text.split())
print(result)
# Out:
# Maison à vendre à Ixelles - 595 000 € - 4 chambres - 243m² - Immoweb Type de bien Appartement Maison Maison et appartement Projet neuf - Appartements Projet neuf - Maisons Maisons à construire Recherche avancée Recherche sur la carte Uniquement les biens avec visite virtuelle Recherche avec un Immoweb code Découvrez nos projets immobiliers neufs Découvrir À louer Type de bien Appartement Maison Maison et appartement Logement étudiant Commerce Recherche avancée Recherche sur la carte Uniquement les biens avec visite virtuelle Recherche avec un Immoweb code Découvrez nos projets immobiliers neufs Découvrir Estimer Estimer Estimer mon bien en ligne Contacter une agence Prix immobilier Carte des prix au m² en Belgique Découvrez nos projets immobiliers neufs Découvrir Professionnels Trouver un professionnel Trouver une agence Trouver un notaire Trouver un promoteur immobilier Découvrez nos projets immobiliers neufs Découvrir Services À votre service Crédit hypothécaire Assurance habitation - incendie Assurance loyer garanti Propriétaire Conseils à la vente Voir tous les services Conseils et inspiration Immoweb Blog Découvrez nos projets immobiliers neufs Découvrir Publier une annonce Se connecter fr en fr nl Javascript est requis Veuillez utiliser un autre navigateur avec Javascript activé. Vers le contenu Maison à vendre Faire offre à partir de 595 000 € 595000€ 4 chambres | 243 m² mètres carrés Immoweb code : 11075842 Immoweb code : 11075842 Aperçu 4 chambres 1 salle de bains 243 m² mètres carrés habitables 110 m² mètres carrés de terrain Disponible le : 15/01/2024 Visite virtuelle Description Ixelles - chouette maison de commerce idéalement située. Informations & visites : +32 2 315 51 71 Ixelles - Idéalement située dans une rue calme, à proximité de l'Avenue Louise, du quartier de la Toison d'Or, du Boulevard de Waterloo et proche de toutes les commodités (transports, commerces, écoles, restaurants, ...), We Invest vous propose cette chouette maison de commerce (2 étages reconnues) à rénover de +/- 280m2 brut + cour intérieur. Elle est actuellement aménagée comme suit : au rez-de-chaussée : un logement avec grand hall d'entrée, salon, salle à manger, cuisine équipée, salle de douche avec wc, buanderie et chambre à coucher de +- 17m2. Au 1er étage : un logement avec salon/salle à manger, cuisine semi-équipée, chambre à coucher de +- 17m2, salle de bain et wc. Au 2ème étage : un logement avec cuisine, salon/salle à manger, salle de douche avec wc et chambre à coucher de +- 17m2. Au 3ème étage : cuisine semi-équipée, salon/salle à manger avec mezzanine, chambre à coucher de +- 17m2, salle de douche et wc. Au sous-sol: caves et local technique. PEB : F, D-,D & G. Chaudières au gaz individuelles. Double vitrage. Disponible à l'acte. A visiter sans plus tarder! Contacter Nos maisons hors de la belgique Maison à vendre France Maison à vendre Espagne Maison à vendre Italie Maison à vendre Luxembourg Maison à vendre Pays-bas À propos Immoweb Presse Emplois Groupe Axel Springer SeLoger.com Immowelt.de Outils Estimer mon bien Carte des prix au m² en Belgique Crédit hypothécaire Assurances Check-list déménagement Aide FAQ Fraude Accessibilité Contactez-nous Suivez-nous Immoweb Blog Facebook Twitter LinkedIn © Immoweb SA/NV 2024 Conditions d'utilisation Gestion des cookies Vie privée 164 - 9244277aa9935b862b993da47ccc3acea6d3c280 - i-09f9ddce4987a82d4

# %%
text = soup.find_all('td', {"class": "classified-table__data"})
text = text[0].get_text().strip()
print(text)

# %%
property_type = classified_data['property']['type']
print(f"Type of Property: {property_type}")

property_subtype = classified_data['property']['subtype']
print(f"Subtype of Property: {property_subtype}")

number_of_rooms = classified_data['property'].get('bedroomCount', 0)
print(f"Number of Rooms: {number_of_rooms}")

furnished = 1 if classified_data['transaction'].get('sale', {}).get('isFurnished', False) else 0
print(f"Furnished: {furnished}")

sale_type = classified_data['transaction']['subtype'] if classified_data['transaction']['subtype'] != 'LIFE_SALE' else None
print(f"Type of Sale: {sale_type}")

price = classified_data['transaction']['sale']['price']
print(f"Price: {price}")



totalBuildableGroundFloorSurface = classified_data['constructionPermit']['totalBuildableGroundFloorSurface']
print(f"Surface of good: {totalBuildableGroundFloorSurface}")
# Out:
# Type of Property: HOUSE
# Subtype of Property: HOUSE
# Number of Rooms: 4
# Furnished: 0
# Type of Sale: BUY_REGULAR
# Price: 595000
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[93], line 21
#      16 price = classified_data['transaction']['sale']['price']
#      17 print(f"Price: {price}")
# ---> 21 totalBuildableGroundFloorSurface = classified_data['transaction']['totalBuildableGroundFloorSurface']
#      22 print(f"Surface of good: {totalBuildableGroundFloorSurface}")
#
# KeyError: 'totalBuildableGroundFloorSurface'
